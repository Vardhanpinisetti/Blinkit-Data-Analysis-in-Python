# %% [markdown]
# ## **DATA ANALYSIS PYTHON PROJECT - BLINKIT ANALYSIS**

# %% [markdown]
# ## **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Sample Data**

# %%
df = pd.read_csv("/content/blink_data.csv")

# %%
df.head(10)
# Out:
#   Item Fat Content Item Identifier              Item Type  \
# 0          Regular           FDX32  Fruits and Vegetables
# 1          Low Fat           NCB42     Health and Hygiene
# 2          Regular           FDR28           Frozen Foods
# 3          Regular           FDL50                 Canned
# 4          Low Fat           DRI25            Soft Drinks
# 5          Low Fat           FDS52           Frozen Foods
# 6          Low Fat           NCU05     Health and Hygiene
# 7          Low Fat           NCD30              Household
# 8          Low Fat           FDW20  Fruits and Vegetables
# 9          Low Fat           FDX25                 Canned
#
#    Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                       2012            OUT049               Tier 1
# 1                       2022            OUT018               Tier 3
# 2                       2016            OUT046               Tier 1
# ...

# %% [markdown]
# ### **Outlet Type**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Outlet Type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### **Outlet Size**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Outlet Size').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### **Outlet Location Type**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Outlet Location Type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### **Item Fat Content**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Item Fat Content').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### **Sales**

# %%
from matplotlib import pyplot as plt
df['Sales'].plot(kind='hist', bins=20, title='Sales')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### **Outlet Type vs Outlet Establishment Year**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['Outlet Type'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Outlet Establishment Year', y='Outlet Type', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ### **Outlet Size vs Outlet Establishment Year**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['Outlet Size'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Outlet Establishment Year', y='Outlet Size', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ### **Outlet Location Type vs Outlet Establishment Year**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['Outlet Location Type'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Outlet Establishment Year', y='Outlet Location Type', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ### **Item Flat COntent vs Outlet Establishment Year**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['Item Fat Content'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='Outlet Establishment Year', y='Item Fat Content', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ### **Outlet Size vs OutLet Type**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Outlet Type'].value_counts()
    for x_label, grp in df.groupby('Outlet Size')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Outlet Size')
_ = plt.ylabel('Outlet Type')

# %% [markdown]
# ### **Outlet Location Type vs Outlet Size**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Outlet Size'].value_counts()
    for x_label, grp in df.groupby('Outlet Location Type')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Outlet Location Type')
_ = plt.ylabel('Outlet Size')

# %% [markdown]
# ### **Item Flat Content vs Outlet Location Type**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Outlet Location Type'].value_counts()
    for x_label, grp in df.groupby('Item Fat Content')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Item Fat Content')
_ = plt.ylabel('Outlet Location Type')

# %% [markdown]
# ### **Sales**

# %%
from matplotlib import pyplot as plt
df['Sales'].plot(kind='line', figsize=(8, 4), title='Sales')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ### **Item Weight**

# %%
from matplotlib import pyplot as plt
df['Item Weight'].plot(kind='line', figsize=(8, 4), title='Item Weight')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ### **Item Visibility**

# %%
from matplotlib import pyplot as plt
df['Item Visibility'].plot(kind='line', figsize=(8, 4), title='Item Visibility')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ### **Outlet Establishment Year**

# %%
from matplotlib import pyplot as plt
df['Outlet Establishment Year'].plot(kind='line', figsize=(8, 4), title='Outlet Establishment Year')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ### **Item Weight vs Sales**

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Item Weight', y='Sales', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### **Item Visibility vs Item Weight**

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Item Visibility', y='Item Weight', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### **Sales vs Rating**

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Sales', y='Rating', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### **Outlet Establishment Year vs Item Visibility**

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Outlet Establishment Year', y='Item Visibility', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### **Item Weight**

# %%
from matplotlib import pyplot as plt
df['Item Weight'].plot(kind='hist', bins=20, title='Item Weight')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### **Item Visibility**

# %%
from matplotlib import pyplot as plt
df['Item Visibility'].plot(kind='hist', bins=20, title='Item Visibility')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### **Outlet Establishment Year**

# %%
from matplotlib import pyplot as plt
df['Outlet Establishment Year'].plot(kind='hist', bins=20, title='Outlet Establishment Year')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.tail(10)
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 8513          Regular           DRY23            Soft Drinks
# 8514          low fat           FDA11           Baking Goods
# 8515          low fat           FDK38                 Canned
# 8516          low fat           FDO38                 Canned
# 8517          low fat           FDG32  Fruits and Vegetables
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
# 8520          low fat           DRE13            Soft Drinks
# 8521              reg           FDT50                  Dairy
# 8522              reg           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 8513                       2018            OUT027               Tier 3
# 8514                       2018            OUT027               Tier 3
# 8515                       2018            OUT027               Tier 3
# ...

# %% [markdown]
# ### **Size of Data**

# %%
print("Size of Data: ", df.shape)
# Out:
# Size of Data:  (8523, 12)

# %% [markdown]
# ### **Field Info**

# %%
df.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %% [markdown]
# ### **Data Types**

# %%
df.dtypes
# Out:
# Item Fat Content              object
# Item Identifier               object
# Item Type                     object
# Outlet Establishment Year      int64
# Outlet Identifier             object
# Outlet Location Type          object
# Outlet Size                   object
# Outlet Type                   object
# Item Visibility              float64
# Item Weight                  float64
# Sales                        float64
# Rating                       float64
# dtype: object

# %% [markdown]
# ### **Data Cleaning**

# %%
print(df['Item Fat Content'].unique())
# Out:
# ['Regular' 'Low Fat' 'low fat' 'reg']

# %%
df['Item Fat Content'] =df['Item Fat Content'].replace({'LF' : 'Low Fat', 'low fat': 'Low Fat', 'reg': 'Regular'})

# %%
print(df['Item Fat Content'].unique())
# Out:
# ['Regular' 'Low Fat']

# %% [markdown]
# ### **BUSINESS REQUIREMENTS**

# %% [markdown]
# ### **KPI REQUIREMENTS**

# %%
#Total Sales
total_sales = df['Sales'].sum()

#Average Sales
avg_sales = df['Sales'].mean()

#No of Items Sold
no_of_items_sold = df['Sales'].count()

#Average Ratings
avg_ratings = df['Rating'].mean()

#Display

print(f"Total Sales: ${total_sales:,.0f}")
print(f"Average Sales: ${avg_sales:,.0f}")
print(f"No of Items Sold: {no_of_items_sold:,.0f}")
print(f"Average Ratings: {avg_ratings:,.0f}")
# Out:
# Total Sales: $1,201,681
# Average Sales: $141
# No of Items Sold: 8,523
# Average Ratings: 4

# %% [markdown]
# ### **CHARTS REQUIREMENTS**

# %% [markdown]
# ### **Total Sales by Fat Content**

# %% [markdown]
# ### **Total Sales by Item Type**

# %% [markdown]
# ### **Fat Content by outlet tier for total sales(Cluster Bar Chart)**

# %%
sales_by_type = df.groupby('Item Type')['Sales'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
bars = plt.bar(sales_by_type.index, sales_by_type.values)

plt.xticks(rotation=-90)
plt.xlabel('Item Type')
plt.ylabel('Total Sales')
plt.title('Total Sales by Item Type')

for bar in bars:
  plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(), f'{bar.get_height():,.0f}', ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Fat Content by outlet tier for total sales(Cluster Bar Chart)**

# %%
grouped = df.groupby(['Outlet Location Type', 'Item Fat Content'])['Sales'].sum().unstack('Item Fat Content')
grouped = grouped[['Regular', 'Low Fat']]

grouped.plot(kind='bar', figsize=(10,7))
plt.xlabel('Outlet Location Tier')
plt.ylabel('Total Sales')
plt.title('Outlet Tier by Item Fat Content')
plt.xticks(rotation=0)
plt.legend(title='Item Fat Content')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Total Sales by Outlet Establishment (Line Chart)**

# %%
sales_by_year = df.groupby('Outlet Establishment Year')['Sales'].sum().sort_index()

plt.figure(figsize=(9,5))
plt.plot(sales_by_year.index, sales_by_year.values, marker='o', linestyle='-')

plt.xlabel('Outlet Establishment Year')
plt.ylabel('Total Sales')
plt.title('Outlet Establishment')

for x,y in zip(sales_by_year.index, sales_by_year.values):
  plt.text(x, y, f'{y:,.0f}', ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Sales by Outlet Size(Donut Chart)**

# %%
sales_by_size = df.groupby('Outlet Size')['Sales'].sum()
fig, ax = plt.subplots(figsize=(6,6))
wedges, texts, autotexts = ax.pie(sales_by_size, labels=sales_by_size.index, autopct='%1.1f%%', startangle=90, pctdistance=0.85)

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig.gca().add_artist(centre_circle)
ax.set_title('Outlet Size')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Sales by Outlet Location(Funnel Chart)**

# %%
import plotly.express as px
sales_by_location = df.groupby('Outlet Location Type')['Sales'].sum().reset_index()
sales_by_location = sales_by_location.sort_values('Sales', ascending=False)

funnel_fig = px.funnel(sales_by_location,
                x='Sales',
                y='Outlet Location Type',
                title='Outlet Location')
funnel_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **All Matrix by outlet type**

# %%
grouped_metrics = df.groupby('Outlet Type').agg({
    'Sales': ['sum', 'mean', 'count'],
    'Rating': 'mean'  })

grouped_metrics.columns = ['Total Sales', 'Average Sales', 'Number of Items', 'Average Rating']
grouped_metrics = grouped_metrics.reset_index()

print("\nMatrix Card: Key Metrics by Outlet Type")
print(grouped_metrics)
# Out:
# Matrix Card: Key Metrics by Outlet Type
#          Outlet Type  Total Sales  Average Sales  Number of Items  \
# 0      Grocery Store  151939.1490     140.294690             1083
# 1  Supermarket Type1  787549.8928     141.213895             5577
# 2  Supermarket Type2  131477.7764     141.678638              928
# 3  Supermarket Type3  130714.6746     139.801791              935
#
#    Average Rating
# 0        3.985873
# 1        3.963242
# 2        3.971228
# 3        3.952941

# %% [markdown]
# ### **Display by Matrix card**

# %%
import matplotlib.font_manager as fm
from IPython.display import display
display(grouped_metrics.style.format({'Total Sales': '{:.2f}', 'Average Sales': '{:.2f}', 'Average Rating': '{:.2f}'}))
# Out:
# <style type="text/css">
# </style>
# <table id="T_1359e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1359e_level0_col0" class="col_heading level0 col0" >Outlet Type</th>
#       <th id="T_1359e_level0_col1" class="col_heading level0 col1" >Total Sales</th>
#       <th id="T_1359e_level0_col2" class="col_heading level0 col2" >Average Sales</th>
#       <th id="T_1359e_level0_col3" class="col_heading level0 col3" >Number of Items</th>
#       <th id="T_1359e_level0_col4" class="col_heading level0 col4" >Average Rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1359e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1359e_row0_col0" class="data row0 col0" >Grocery Store</td>
#       <td id="T_1359e_row0_col1" class="data row0 col1" >151939.15</td>
#       <td id="T_1359e_row0_col2" class="data row0 col2" >140.29</td>
# ...
